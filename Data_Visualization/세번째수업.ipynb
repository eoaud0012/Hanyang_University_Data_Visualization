# %%
import requests

# %%
import bs4

# %%
urlobj = requests.get("http://www.pythonscraping.com/pages/warandpeace.html").text

# %%
bsobj = bs4.BeautifulSoup(urlobj, "html.parser")

# %%
bsobj
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Jane Austen - Wikipedia</title>
# ...

# %%
vlista
# Out:
# []

# %%
print(vlista)
# Out:
# []

# %%
vlista[:1]
# Out:
# [<span style="white-space:nowrap;"> 1810</span>]

# %%
vlista[:2]
# Out:
# [<span style="white-space:nowrap;"> 1810</span>,
#  <span style="display:none">(<span class="bday">1775-12-16</span>)</span>]

# %%
vlista[:3]
# Out:
# [<span style="white-space:nowrap;"> 1810</span>,
#  <span style="display:none">(<span class="bday">1775-12-16</span>)</span>,
#  <span class="bday">1775-12-16</span>]

# %%
vlista[:4]
# Out:
# [<span style="white-space:nowrap;"> 1810</span>,
#  <span style="display:none">(<span class="bday">1775-12-16</span>)</span>,
#  <span class="bday">1775-12-16</span>,
#  <span style="display:none">(1817-07-18)</span>]

# %%
vlistb = bsobj.findAll("span", {'class': "red"})

# %%
vlistb
# Out:
# [<span class="red">Well, Prince, so Genoa and Lucca are now just family estates of the
#  Buonapartes. But I warn you, if you don't tell me that this means war,
#  if you still try to defend the infamies and horrors perpetrated by
#  that Antichrist- I really believe he is Antichrist- I will have
#  nothing more to do with you and you are no longer my friend, no longer
#  my 'faithful slave,' as you call yourself! But how do you do? I see
#  I have frightened you- sit down and tell me all the news.</span>,
#  <span class="red">If you have nothing better to do, Count [or Prince], and if the
#  prospect of spending an evening with a poor invalid is not too
#  terrible, I shall be very charmed to see you tonight between 7 and 10-
#  Annette Scherer.</span>,
#  <span class="red">Heavens! what a virulent attack!</span>,
#  <span class="red">First of all, dear friend, tell me how you are. Set your friend's
#  mind at rest,</span>,
# ...

# %%
vlistb[:1]
# Out:
# []

# %%
vlistb[:2]
# Out:
# []

# %%
bsobj
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Jane Austen - Wikipedia</title>
# ...

# %%
vlistb
# Out:
# []

# %%
vlistb = bsobj.findAll("span", {"class":"green"})

# %%
vlistb[:2]
# Out:
# []

# %%
#mw-content-text > div > div.div-col.columns.column-width

# %%
vlistb
# Out:
# []

# %%
urlobj = urllib.request.urlopen("https://en.wikipedia.org/wiki/Jane_Austen#List_of_works")

# %%
vlist1 = bsobj.find("div", {"class" : "div-col columns column-width"})

# %%
vlist1
# Out:
# <div class="div-col columns column-width" style="-moz-column-width: 25em; -webkit-column-width: 25em; column-width: 25em;">
# <p><b>Novels</b>
# </p>
# <ul><li><i><a href="/wiki/Sense_and_Sensibility" title="Sense and Sensibility">Sense and Sensibility</a></i> (1811)</li>
# <li><i><a href="/wiki/Pride_and_Prejudice" title="Pride and Prejudice">Pride and Prejudice</a></i> (1813)</li>
# <li><i><a href="/wiki/Mansfield_Park" title="Mansfield Park">Mansfield Park</a></i> (1814)</li>
# <li><i><a href="/wiki/Emma_(novel)" title="Emma (novel)">Emma</a></i> (1815)</li>
# <li><i><a href="/wiki/Northanger_Abbey" title="Northanger Abbey">Northanger Abbey</a></i> (1818, posthumous)</li>
# <li><i><a href="/wiki/Persuasion_(novel)" title="Persuasion (novel)">Persuasion</a></i> (1818, posthumous)</li>
# <li><i><a href="/wiki/Lady_Susan" title="Lady Susan">Lady Susan</a></i> (1871, posthumous)</li></ul>
# <p><b>Unfinished fiction</b>
# </p>
# ...

# %%
import urllib.request

# %%
vurlobj = urllib.request.urlopen("https://en.wikipedia.org/wiki/Jane_Austen#List_of_works")

# %%
vbsobj = bs4.BeautifulSoup(vurlobj, "html.parser")

# %%
vbswrite = vbsobj.prettify()

# %%
with open("vfilesaved", "w", encoding="utf-8") as vfileobj:
    vfileobj.write(vbswrite)

# %%
urlobj = urllib.request.urlopen("http://www.pythonscraping.com/pages/warandpeace.html")

# %%
bsobj = bs4.BeautifulSoup(urlobj, "html.parser")

# %%
vlistb = bsobj.findAll("span", {"class":"green"})

# %%
vlistb
# Out:
# [<span class="green">Anna
#  Pavlovna Scherer</span>, <span class="green">Empress Marya
# ...

# %%
for listfor in vlistb:
    print(listfor.get_text()
# Out:
#   File "<ipython-input-109-7a1a21a14b7d>", line 2
#     print(listfor.get_text()
#                             ^
# SyntaxError: unexpected EOF while parsing

# %%
for listfor in vlistb:
    print(listfor.get_text())
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
text_list = []

# %%
for listfor in vlistb:
    text_list.append(listfor.get_text())

# %%
text_list
# Out:
# ['Anna\nPavlovna Scherer',
#  'Empress Marya\nFedorovna',
#  'Prince Vasili Kuragin',
#  'Anna Pavlovna',
#  'St. Petersburg',
#  'the prince',
#  'Anna Pavlovna',
#  'Anna Pavlovna',
#  'the prince',
#  'the prince',
#  'the prince',
#  'Prince Vasili',
#  'Anna Pavlovna',
#  'Anna Pavlovna',
#  'the prince',
#  'Wintzingerode',
#  'King of Prussia',
#  'le Vicomte de Mortemart',
#  'Montmorencys',
#  'Rohans',
#  'Abbe Morio',
#  'the Emperor',
#  'the prince',
#  'Prince Vasili',
#  'Dowager Empress Marya Fedorovna',
#  'the baron',
#  'Anna Pavlovna',
#  'the Empress',
#  'the Empress',
#  "Anna Pavlovna's",
#  'Her Majesty',
#  'Baron\nFunke',
#  'The prince',
#  'Anna\nPavlovna',
#  'the Empress',
#  'The prince',
#  'Anatole',
#  'the prince',
#  'The prince',
#  'Anna\nPavlovna',
#  'Anna Pavlovna']

# %%
text_list_write = text_list.prettify()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-ec3aa9042427> in <module>
# ----> 1 text_list_write = text_list.prettify()
#
# AttributeError: 'list' object has no attribute 'prettify'

# %%
with open("text_list_saved", "w", encoding="utf-8") as vfileobj:
    vfileobj.write(text_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-2d4e419dc390> in <module>
#       1 with open("text_list_saved", "w", encoding="utf-8") as vfileobj:
# ----> 2     vfileobj.write(text_list)
#
# TypeError: write() argument must be str, not list

# %%
vbswrite = vlistb.get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-b135200af027> in <module>
# ----> 1 vbswrite = vlistb.get_text()
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
vlistb
# Out:
# [<span class="green">Anna
#  Pavlovna Scherer</span>, <span class="green">Empress Marya
# ...

# %%
vlistb.get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-0dac4b7ae15a> in <module>
# ----> 1 vlistb.get_text()
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
vbswrite = vlistb.get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-b135200af027> in <module>
# ----> 1 vbswrite = vlistb.get_text()
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
vlistb
# Out:
# [<span class="green">Anna
#  Pavlovna Scherer</span>, <span class="green">Empress Marya
# ...

# %%
for tmp in vlistb:
    vbswrite = tmp.get_text()

# %%
vbswrite = []

# %%
for tmp in vlistb:
    vbswrite = tmp.strings

# %%
vbswrite
# Out:
# <generator object Tag._all_strings at 0x000001F3F408BC00>

# %%
vurlobj = urllib.request.urlopen("https://en.wikipedia.org/wiki/Jane_Austen#List_of_works")

# %%
vbswrite = tmp.strings

# %%
vgswrite
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-0b666389abf3> in <module>
# ----> 1 vgswrite
#
# NameError: name 'vgswrite' is not defined

# %%
vbswrite
# Out:
# <generator object Tag._all_strings at 0x000001F3F408BB88>

# %%
vbsobj = bs4.BeautifulSoup(vurlobj, "html.parser")

# %%
vbstag = vbsobj.find("div", {"class" : "div-col columns column-width"})

# %%
vbswrite = vbstag.get_text()

# %%
vbswrite
# Out:
# '\nNovels\n\nSense and Sensibility (1811)\nPride and Prejudice (1813)\nMansfield Park (1814)\nEmma (1815)\nNorthanger Abbey (1818, posthumous)\nPersuasion (1818, posthumous)\nLady Susan (1871, posthumous)\nUnfinished fiction\n\nThe Watsons (1804)\nSanditon (1817)\nOther works\n\nSir Charles Grandison (adapted play) (1793, 1800)[p]\nPlan of a Novel (1815)\nPoems (1796–1817)\nPrayers (1796–1817)\nLetters (1796–1817)\nJuvenilia\xa0— Volume the First (1787–1793)[q]\n\nFrederic & Elfrida\nJack & Alice\nEdgar & Emma\nHenry and Eliza\nThe Adventures of Mr. Harley\nSir William Mountague\nMemoirs of Mr. Clifford\nThe Beautifull Cassandra\nAmelia Webster\nThe Visit\nThe Mystery\nThe Three Sisters\nA beautiful description\nThe generous Curate\nOde to Pity\nJuvenilia\xa0— Volume the Second (1787–1793)\n\nLove and Freindship\nLesley Castle\nThe History of England\nA Collection of Letters\nThe female philosopher\nThe first Act of a Comedy\nA Letter from a Young Lady\nA Tour through Wales\nA Tale\n
# ...

# %%
with open("vfilesaved2", "w", encoding="utf-8") as vfileobj:
    vfileobj.write(vbswrite)

# %%
import urllib.request

# %%
import bs4

# %%
vurlobj = urllib.request.urlopen("https://en.wikipedia.org/wiki/Jane_Austen#List_of_works")

# %%
vbsobj = bs4.BeautifulSoup(vurlobj, "html.parser")

# %%
vbstag = vbsobj.find("div", {"class" : "div-col columns column-width"})

# %%
vbstag
# Out:
# <div class="div-col columns column-width" style="-moz-column-width: 25em; -webkit-column-width: 25em; column-width: 25em;">
# <p><b>Novels</b>
# </p>
# <ul><li><i><a href="/wiki/Sense_and_Sensibility" title="Sense and Sensibility">Sense and Sensibility</a></i> (1811)</li>
# <li><i><a href="/wiki/Pride_and_Prejudice" title="Pride and Prejudice">Pride and Prejudice</a></i> (1813)</li>
# <li><i><a href="/wiki/Mansfield_Park" title="Mansfield Park">Mansfield Park</a></i> (1814)</li>
# <li><i><a href="/wiki/Emma_(novel)" title="Emma (novel)">Emma</a></i> (1815)</li>
# <li><i><a href="/wiki/Northanger_Abbey" title="Northanger Abbey">Northanger Abbey</a></i> (1818, posthumous)</li>
# <li><i><a href="/wiki/Persuasion_(novel)" title="Persuasion (novel)">Persuasion</a></i> (1818, posthumous)</li>
# <li><i><a href="/wiki/Lady_Susan" title="Lady Susan">Lady Susan</a></i> (1871, posthumous)</li></ul>
# <p><b>Unfinished fiction</b>
# </p>
# ...

# %%
vbstaglibb = vbstag.findAll("li")

# %%
vbstaglibb
# Out:
# [<li><i><a href="/wiki/Sense_and_Sensibility" title="Sense and Sensibility">Sense and Sensibility</a></i> (1811)</li>,
#  <li><i><a href="/wiki/Pride_and_Prejudice" title="Pride and Prejudice">Pride and Prejudice</a></i> (1813)</li>,
#  <li><i><a href="/wiki/Mansfield_Park" title="Mansfield Park">Mansfield Park</a></i> (1814)</li>,
#  <li><i><a href="/wiki/Emma_(novel)" title="Emma (novel)">Emma</a></i> (1815)</li>,
#  <li><i><a href="/wiki/Northanger_Abbey" title="Northanger Abbey">Northanger Abbey</a></i> (1818, posthumous)</li>,
#  <li><i><a href="/wiki/Persuasion_(novel)" title="Persuasion (novel)">Persuasion</a></i> (1818, posthumous)</li>,
#  <li><i><a href="/wiki/Lady_Susan" title="Lady Susan">Lady Susan</a></i> (1871, posthumous)</li>,
#  <li><i><a href="/wiki/The_Watsons" title="The Watsons">The Watsons</a></i> (1804)</li>,
#  <li><i><a href="/wiki/Sanditon" title="Sanditon">Sanditon</a></i> (1817)</li>,
# ...

# %%
vstrlist=[]

# %%
for vbstaglisb in vbstaglibb:
    vbstagstr = vbstaglisb.strings
    vstrlist.append(vbstagstr)

# %%
vbstagstr
# Out:
# <generator object Tag._all_strings at 0x000001F3F4ACF750>

# %%
vstrlist
# Out:
# [<generator object Tag._all_strings at 0x000001F3F4AC54F8>,
#  <generator object Tag._all_strings at 0x000001F3F4AC5570>,
#  <generator object Tag._all_strings at 0x000001F3F4AC5480>,
#  <generator object Tag._all_strings at 0x000001F3F4AC55E8>,
#  <generator object Tag._all_strings at 0x000001F3F4AC5660>,
#  <generator object Tag._all_strings at 0x000001F3F4AC56D8>,
#  <generator object Tag._all_strings at 0x000001F3F4AC5750>,
#  <generator object Tag._all_strings at 0x000001F3F4AC57C8>,
#  <generator object Tag._all_strings at 0x000001F3F4AC5840>,
#  <generator object Tag._all_strings at 0x000001F3F4AC58B8>,
#  <generator object Tag._all_strings at 0x000001F3F4AC5930>,
#  <generator object Tag._all_strings at 0x000001F3F4AC59A8>,
#  <generator object Tag._all_strings at 0x000001F3F4AC5A20>,
#  <generator object Tag._all_strings at 0x000001F3F4AC5A98>,
#  <generator object Tag._all_strings at 0x000001F3F4AC5B10>,
#  <generator object Tag._all_strings at 0x000001F3F4AC5B88>,
# ...

# %%
vwordwrite=str(vstrlist)

# %%
vwordwrite
# Out:
# '[<generator object Tag._all_strings at 0x000001F3F4AC54F8>, <generator object Tag._all_strings at 0x000001F3F4AC5570>, <generator object Tag._all_strings at 0x000001F3F4AC5480>, <generator object Tag._all_strings at 0x000001F3F4AC55E8>, <generator object Tag._all_strings at 0x000001F3F4AC5660>, <generator object Tag._all_strings at 0x000001F3F4AC56D8>, <generator object Tag._all_strings at 0x000001F3F4AC5750>, <generator object Tag._all_strings at 0x000001F3F4AC57C8>, <generator object Tag._all_strings at 0x000001F3F4AC5840>, <generator object Tag._all_strings at 0x000001F3F4AC58B8>, <generator object Tag._all_strings at 0x000001F3F4AC5930>, <generator object Tag._all_strings at 0x000001F3F4AC59A8>, <generator object Tag._all_strings at 0x000001F3F4AC5A20>, <generator object Tag._all_strings at 0x000001F3F4AC5A98>, <generator object Tag._all_strings at 0x000001F3F4AC5B10>, <generator object Tag._all_strings at 0x000001F3F4AC5B88>, <generator object Tag._all_strings at 0x000001F3F4AC
# ...

# %%
type vbsobj
# Out:
#   File "<ipython-input-156-5217ac5aca7f>", line 1
#     type vbsobj
#               ^
# SyntaxError: invalid syntax

# %%
type(vbsobj)
# Out:
# bs4.BeautifulSoup

# %%
type(vurlobj)
# Out:
# http.client.HTTPResponse

# %%
type(vbstag)
# Out:
# bs4.element.Tag

# %%
type(vbstaglibb)
# Out:
# bs4.element.ResultSet

# %%
type(vstrlist)
# Out:
# list

# %%
type(vbstaglisb)
# Out:
# bs4.element.Tag

# %%
type(vbstaglibb)
# Out:
# bs4.element.ResultSet

# %%
type(vbstagstr)
# Out:
# generator

# %%
import urllib.request

# %%
import bs4

# %%
vurlobj = urllib.request.urlopen("https://en.wikipedia.org/wiki/Jane_Austen#List_of_works")

# %%
vbsobj = bs4.BeautifulSoup(vurlobj, "html.parser")

# %%
vbstag = vbsobj.find("div", {"class" : "div-col columns column-width"})

# %%
vbstaglibb = vbstag.findAll("li")

# %%
vstrlist = []

# %%
for vbstaglisb in vbstaglibb:
    vbstagstr = vbstaglisb.strings
    vbstagstrlist = list(vbstagstr)
    vstrlist.append(vbstagstrlist)
vwordwrite=str(vstrlist)

# %%
vstrlist
# Out:
# [['Sense and Sensibility', ' (1811)'],
#  ['Pride and Prejudice', ' (1813)'],
#  ['Mansfield Park', ' (1814)'],
#  ['Emma', ' (1815)'],
#  ['Northanger Abbey', ' (1818, posthumous)'],
#  ['Persuasion', ' (1818, posthumous)'],
#  ['Lady Susan', ' (1871, posthumous)'],
#  ['The Watsons', ' (1804)'],
#  ['Sanditon', ' (1817)'],
#  ['Sir Charles Grandison', ' (', 'adapted', ' play) (1793, 1800)', '[p]'],
#  ['Plan of a Novel', ' (1815)'],
#  ['Poems (1796–1817)'],
#  ['Prayers (1796–1817)'],
#  ['Letters (1796–1817)'],
#  ['Frederic & Elfrida'],
#  ['Jack & Alice'],
#  ['Edgar & Emma'],
#  ['Henry and Eliza'],
#  ['The Adventures of Mr. Harley'],
#  ['Sir William Mountague'],
#  ['Memoirs of Mr. Clifford'],
#  ['The Beautifull Cassandra'],
#  ['Amelia Webster'],
#  ['The Visit'],
#  ['The Mystery'],
#  ['The Three Sisters'],
#  ['A beautiful description'],
#  ['The generous Curate'],
#  ['Ode to Pity'],
#  ['Love and Freindship'],
#  ['Lesley Castle'],
#  ['The History of England'],
# ...

# %%
vwordwrite
# Out:
# "[['Sense and Sensibility', ' (1811)'], ['Pride and Prejudice', ' (1813)'], ['Mansfield Park', ' (1814)'], ['Emma', ' (1815)'], ['Northanger Abbey', ' (1818, posthumous)'], ['Persuasion', ' (1818, posthumous)'], ['Lady Susan', ' (1871, posthumous)'], ['The Watsons', ' (1804)'], ['Sanditon', ' (1817)'], ['Sir Charles Grandison', ' (', 'adapted', ' play) (1793, 1800)', '[p]'], ['Plan of a Novel', ' (1815)'], ['Poems (1796–1817)'], ['Prayers (1796–1817)'], ['Letters (1796–1817)'], ['Frederic & Elfrida'], ['Jack & Alice'], ['Edgar & Emma'], ['Henry and Eliza'], ['The Adventures of Mr. Harley'], ['Sir William Mountague'], ['Memoirs of Mr. Clifford'], ['The Beautifull Cassandra'], ['Amelia Webster'], ['The Visit'], ['The Mystery'], ['The Three Sisters'], ['A beautiful description'], ['The generous Curate'], ['Ode to Pity'], ['Love and Freindship'], ['Lesley Castle'], ['The History of England'], ['A Collection of Letters'], ['The female philosopher'], ['The first Act of a Comedy'], ['A Lett
# ...

# %%
vbstagstrlist
# Out:
# ['Catherine, or The Bower']

# %%
vbstgstr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-177-4269fac92a41> in <module>
# ----> 1 vbstgstr
#
# NameError: name 'vbstgstr' is not defined

# %%
vbstagstr
# Out:
# <generator object Tag._all_strings at 0x000001F3F44095E8>

# %%
with open("vfilesaved3", "w", encoding = 'utf-8') as vfileobj:
    vfileobj.write(vwordwrite)

# %%
vlist1
# Out:
# <div class="div-col columns column-width" style="-moz-column-width: 25em; -webkit-column-width: 25em; column-width: 25em;">
# <p><b>Novels</b>
# </p>
# <ul><li><i><a href="/wiki/Sense_and_Sensibility" title="Sense and Sensibility">Sense and Sensibility</a></i> (1811)</li>
# <li><i><a href="/wiki/Pride_and_Prejudice" title="Pride and Prejudice">Pride and Prejudice</a></i> (1813)</li>
# <li><i><a href="/wiki/Mansfield_Park" title="Mansfield Park">Mansfield Park</a></i> (1814)</li>
# <li><i><a href="/wiki/Emma_(novel)" title="Emma (novel)">Emma</a></i> (1815)</li>
# <li><i><a href="/wiki/Northanger_Abbey" title="Northanger Abbey">Northanger Abbey</a></i> (1818, posthumous)</li>
# <li><i><a href="/wiki/Persuasion_(novel)" title="Persuasion (novel)">Persuasion</a></i> (1818, posthumous)</li>
# <li><i><a href="/wiki/Lady_Susan" title="Lady Susan">Lady Susan</a></i> (1871, posthumous)</li></ul>
# <p><b>Unfinished fiction</b>
# </p>
# ...

# %%
vtaglist = []

# %%
for vlistfa in vlist1.findAll("li"):
    vtaga = list(vlistfa.strings)
    vtaglist.append(vtaga)
    print("-", vtaga)
# Out:
# - ['Sense and Sensibility', ' (1811)']
# - ['Pride and Prejudice', ' (1813)']
# - ['Mansfield Park', ' (1814)']
# - ['Emma', ' (1815)']
# - ['Northanger Abbey', ' (1818, posthumous)']
# - ['Persuasion', ' (1818, posthumous)']
# - ['Lady Susan', ' (1871, posthumous)']
# - ['The Watsons', ' (1804)']
# - ['Sanditon', ' (1817)']
# - ['Sir Charles Grandison', ' (', 'adapted', ' play) (1793, 1800)', '[p]']
# - ['Plan of a Novel', ' (1815)']
# - ['Poems (1796–1817)']
# - ['Prayers (1796–1817)']
# - ['Letters (1796–1817)']
# - ['Frederic & Elfrida']
# - ['Jack & Alice']
# - ['Edgar & Emma']
# - ['Henry and Eliza']
# - ['The Adventures of Mr. Harley']
# - ['Sir William Mountague']
# - ['Memoirs of Mr. Clifford']
# - ['The Beautifull Cassandra']
# - ['Amelia Webster']
# - ['The Visit']
# - ['The Mystery']
# - ['The Three Sisters']
# - ['A beautiful description']
# - ['The generous Curate']
# - ['Ode to Pity']
# - ['Love and Freindship']
# - ['Lesley Castle']
# - ['The History of England']
# ...
